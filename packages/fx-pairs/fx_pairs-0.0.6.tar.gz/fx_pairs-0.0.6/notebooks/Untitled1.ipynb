# %%
import pandas as pd

# %%
backtest = pd.read_pickle('../dma.pickle')

# %%
backtest[['short_mavg', 'long_mavg']].plot()
# Out:
# <Axes: >

# %%
pd.concat(backtest['positions'].map(pd.DataFrame).to_list(),
          keys=backtest.index).droplevel(1).set_index('sid', append=True).plot()
# Out:
# <Axes: xlabel='None,sid'>

# %%
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %%
# %%zipline --start 2023-1-1 --end 2023-11-1 --no-benchmark --bundle yahoo-fx -o backtest
# from zipline import api
# from zipline.algorithm import TradingAlgorithm
# from zipline._protocol import BarData
#
# def initialize(context: TradingAlgorithm):
#     pass
#
# def handle_data(context: TradingAlgorithm, data):
#     api.order(symbol('CHF=X'), 1000)
#     api.record(CHF=data.current(symbol('CHF=X'), "price"))
# Out:
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# <class 'zipline._protocol.BarData'>
# ...

# %%
backtest = _

# %%
# Out:
#                                         period_open              period_close  \
# 2023-01-03 21:00:00+00:00 2023-01-03 14:31:00+00:00 2023-01-03 21:00:00+00:00
# 2023-01-04 21:00:00+00:00 2023-01-04 14:31:00+00:00 2023-01-04 21:00:00+00:00
# 2023-01-05 21:00:00+00:00 2023-01-05 14:31:00+00:00 2023-01-05 21:00:00+00:00
# 2023-01-06 21:00:00+00:00 2023-01-06 14:31:00+00:00 2023-01-06 21:00:00+00:00
# 2023-01-09 21:00:00+00:00 2023-01-09 14:31:00+00:00 2023-01-09 21:00:00+00:00
# ...                                             ...                       ...
# 2023-10-26 20:00:00+00:00 2023-10-26 13:31:00+00:00 2023-10-26 20:00:00+00:00
# 2023-10-27 20:00:00+00:00 2023-10-27 13:31:00+00:00 2023-10-27 20:00:00+00:00
# 2023-10-30 20:00:00+00:00 2023-10-30 13:31:00+00:00 2023-10-30 20:00:00+00:00
# 2023-10-31 20:00:00+00:00 2023-10-31 13:31:00+00:00 2023-10-31 20:00:00+00:00
# 2023-11-01 20:00:00+00:00 2023-11-01 13:31:00+00:00 2023-11-01 20:00:00+00:00
#
# ...
